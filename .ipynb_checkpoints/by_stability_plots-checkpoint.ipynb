# %% [markdown]
# ## Stability in the BY Model

# %%
include("src/stability_plots.jl")
# Out:
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'multi_from_single :: Tuple{Any,Any}' in module 'Main'.
# WARNING: replacing docs for 'discretize_by :: Tuple{BYconsumption,Integer,Integer}' in module 'Main'.
# WARNING: replacing docs for 'SSYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'SSYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'split_index :: Tuple{Any,Any}' in module 'Main'.
# WARNING: replacing docs for 'discretize_ssy_process :: Tuple{SSYconsumption,Integer,Integer,Integer}' in module 'Main'.
# ...

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("by", [10, 10], :ψ, 1.02, 2.2, :μ, 0.005, 0.0057, G=25, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb8276c2828>)

# %%
stability_plot("by", [10, 10], :ψ, 1.02, 2.2, :μ, 0.005, 0.0057, G=25, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb830f65be0>)

# %% [markdown]
# ### psi vs beta

# %%
ez = EpsteinZinSSY()
ssy = SSYconsumption()
stability_plot(ez, ssy, [6, 6, 6], :β, 0.975, 0.9999, :ψ, 1.25, 4.0, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6705a9af60>)

# %%
ez = EpsteinZinSSY()
ssy = SSYconsumption()
stability_plot(ez, ssy, [6, 6, 6], :β, 0.975, 0.9999, :ψ, 1.25, 4.0, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f6705967c88>)
