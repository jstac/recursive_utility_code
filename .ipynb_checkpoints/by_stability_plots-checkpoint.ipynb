# %% [markdown]
# ## Stability in the BY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinBY()
by = BYConsumption()
# Out:
# BYConsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6)

# %%
compute_mm_coef(ez, by)
# Out:
# 1.0086927248529742

# %%
@time compute_spec_rad_coeff(ez, by)
# Out:
#   1.225132 seconds (713.41 k allocations: 97.171 MiB, 6.26% gc time)
# 0.21533738817565018

# %%
(1 - ez.γ) / (1 - 1/ez.ψ)
# Out:
# -26.999999999999996

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("by", :ψ, 1.1, 4.5, :μ_c, 0.0012, 0.005, G=20, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e7fbb5b38>)

# %%
@time stability_plot("by", :ψ, 1.1, 4.5, :μ_c, 0.0012, 0.005, G=20, coords=(25, 25))
# Out:
# 113.
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7e7fb1d630>)
# 866703 seconds (3.06 M allocations: 23.985 GiB, 2.01% gc time)
