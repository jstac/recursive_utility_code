# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# stability_plot (generic function with 1 method)

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", :ψ, 1.1, 4.5, :μ_c, 0.0012, 0.005, G=12, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff92d3eecc0>)

# %%
stability_plot("ssy", :ψ, 1.1, 4.5, :μ_c, 0.0012, 0.005, G=20, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb822c6d748>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy",  :β, 0.996, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f83b38fa898>)

# %%
stability_plot("ssy", :β, 0.996, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f83b3942c18>)
