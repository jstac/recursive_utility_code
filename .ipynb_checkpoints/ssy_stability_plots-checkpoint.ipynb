# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinSSY()
# Out:
# EpsteinZin{Float64}(1.97, 8.89, 0.999)

# %%
ssy = SSYconsumption()
# Out:
# SSYconsumption{Float64}(0.0016, 0.987, 0.215, 0.0032, 1.0, 0.992, 0.06244997998398398, 0.991, 0.09797958971132711)

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", [6, 6, 6], :ψ, 1.02, 2.1, :μ, 0.0005, 0.006, G=25, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ef0eed908>)

# %%
stability_plot("ssy", [6, 6, 6], :ψ, 1.02, 2.1, :μ, 0.0005, 0.006, G=25)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ee7830860>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy", [6, 6, 6], :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ee6f019e8>)

# %%
stability_plot("ssy", [6, 6, 6], :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8edfa7b198>)

# %% [markdown]
# ### rho vs beta
