# %% [markdown]
# ## Stability in the BY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinBY()
by = BYConsumption()
# Out:
# BYConsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6)

# %%
compute_mm_coef(ez, by)
# Out:
# 1.0086927306728068

# %%
@time compute_spec_rad_coef(ez, by, M=1000, N=5000)
# Out:
#   0.262874 seconds (77.25 k allocations: 194.463 MiB, 2.92% gc time)
# 0.28880407519522494

# %%
0.26^(1/ez.θ)
# Out:
# 1.0511571622055882

# %%
@time simulate(by, ts_length=2000);
# Out:
#   0.000071 seconds (11 allocations: 63.344 KiB)

# %%
(1 - ez.γ) / (1 - 1/ez.ψ)
# Out:
# -26.999999999999996

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("by", :ψ, 1.1, 4.0, :μ_c, 0.0012, 0.0045, G=20, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f69769aa198>)

# %%
stability_plot("by", :ψ, 1.1, 4.0, :μ_c, 0.0012, 0.0045, G=20, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f69768c01d0>)
