# %% [markdown]
# ## Stability in the BY Model

# %%
include("src/stability_plots.jl")
# Out:
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'compute_bounds :: Tuple{BYconsumption}' in module 'Main'.
# WARNING: replacing docs for 'BYComputableModel :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'K_interp! :: Tuple{BYComputableModel}' in module 'Main'.
# WARNING: replacing docs for 'compute_spec_rad_coeff :: Tuple{EpsteinZin,BYconsumption}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'SSYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'SSYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'compute_bounds :: Tuple{SSYconsumption}' in module 'Main'.
# WARNING: replacing docs for 'SSYComputableModel :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'K_interp! :: Tuple{SSYComputableModel}' in module 'Main'.
# WARNING: replacing docs for 'compute_spec_rad_coeff :: Tuple{EpsteinZin,SSYconsumption}' in module 'Main'.
# WARNING: replacing docs for 'compute_mm_coef :: Tuple{EpsteinZin,SSYconsumption}' in module 'Main'.
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinBY()
by = BYconsumption()
# Out:
# BYconsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6)

# %%
compute_mm_coef_interp(ez, by)
# Out:
# 1.0086927248529742

# %%
@time compute_spec_rad_coeff(ez, by)
# Out:
#   0.436227 seconds (46.74 k allocations: 63.276 MiB, 0.90% gc time)
# 0.21533738817565018

# %%
(1 - ez.γ) / (1 - 1/ez.ψ)
# Out:
# -26.999999999999996

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("by", :ψ, 1.1, 4.5, :μ, 0.0012, 0.005, G=20, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f7fcb8849b0>)

# %%
@time stability_plot("by", :ψ, 1.1, 4.5, :μ, 0.0012, 0.005, G=20, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f800436c860>)
# 138.525814 seconds (3.04 M allocations: 23.984 GiB, 2.02% gc time)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("by", [10, 10], :β, 0.985, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f52a8f64e10>)

# %%
stability_plot("by", [6, 6], :β, 0.985, 0.99999, :ψ, 1.25, 10.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f52aec7c588>)
