# %%
include("src/by_consumption.jl")
# Out:
# WARNING: replacing docs for 'BYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumptionDiscretized :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'single_to_multi :: Tuple{Any,Any}' in module 'Main'.
# WARNING: replacing docs for 'discretize :: Tuple{BYconsumption,Integer,Integer}' in module 'Main'.
# WARNING: replacing docs for 'discretize :: Tuple{BYconsumption,Any}' in module 'Main'.
# WARNING: replacing docs for 'compute_bounds :: Tuple{BYconsumption}' in module 'Main'.
# compute_bounds

# %%
using PyPlot
plt = PyPlot
# Out:
# PyPlot

# %%
by = BYconsumption()
# Out:
# BYconsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6)

# %%
byd1 = discretize(by, 10, 10)
# Out:
# BYconsumptionDiscretized(BYconsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6), 10, 10, [-0.00274011 -0.0021312 … 0.0021312 0.00274011; -0.00339236 -0.0026385 … 0.0026385 0.00339236; … ; -0.00628549 -0.00488871 … 0.00488871 0.00628549; -0.006596 -0.00513023 … 0.00513023 0.006596], [0.00423182, 0.00523915, 0.00608186, 0.00682125, 0.00748798, 0.00810001, 0.00866894, 0.00920277, 0.00970728, 0.0101868], [-0.00274011 -0.0021312 … 0.00513023 0.006596; 0.00423182 0.00423182 … 0.0101868 0.0101868], [0.857537 0.0818972 … 2.72517e-35 3.2131e-38; 0.00909969 0.85831 … 2.28283e-33 3.02796e-36; … ; 3.02796e-36 2.28283e-33 … 0.85831 0.00909969; 3.2131e-38 2.72517e-35 … 0.0818972 0.857537])

# %%
s1, z1, c1 = sim_consumption(byd1, ts_length=80000);

# %%
fig, ax = plt.subplots()
ax[:plot](c1, alpha=0.75)
ax[:set](ylim=(-0.05, 0.05))
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb1282a7a20>)

# %%
fig, ax = plt.subplots()
ax[:plot](z1, alpha=0.75)
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb128278b38>)

# %%
fig, ax = plt.subplots()
ax[:plot](s1, alpha=0.75)
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb12f8117b8>)

# %%
using StatsBase

# %%
quantile(s1, 0.01)
# Out:
# 0.005239145674540663

# %%
compute_bounds(by)
# Out:
# (-0.003788895069644507, 0.0023848008177465743, 0.005917202188132667, 0.009609717808571085)
