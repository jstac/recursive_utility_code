# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinSSY()
# Out:
# EpsteinZin{Float64}(1.97, 8.89, 0.999)

# %%
ssy = SSYconsumption()
# Out:
# SSYconsumption{Float64}(0.0016, 0.987, 0.215, 0.0032, 1.0, 0.992, 0.06244997998398398, 0.991, 0.09797958971132711)

# %%
ssyd = discretize(ssy, 10, 10, 10);

# %%
compute_mm_coef(ez, ssyd)
# Out:
# 1.0672039167101457

# %%
@time compute_spec_rad(ez, ssyd)
# Out:
#   1.615629 seconds (3.17 M allocations: 78.393 MiB, 0.67% gc time)
# 1.0683240099046818

# %%
(1 - ez.γ) / (1 - 1/ez.ψ)
# Out:
# -16.0240206185567

# %%
int_vec = [14, 14, 14]
# Out:
# 3-element Array{Int64,1}:
#  14
#  14
#  14

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", int_vec, :ψ, 1.01, 2.5, :μ, 0.0005, 0.007, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fef85189c50>)

# %%
stability_plot("ssy", int_vec, :ψ, 1.01, 2.5, :μ, 0.0005, 0.007, G=14)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3ef0dda7f0>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy", int_vec, :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=6, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3efad6b630>)

# %%
stability_plot("ssy", int_vec, :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=6)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3ef1079d30>)

# %%
ssyd = discretize(ssy, 14, 4, 4);

# %%
ez = EpsteinZinSSY(ψ=4.0, γ=1.5)
# Out:
# EpsteinZin{Float64}(4.0, 1.5, 0.999)

# %%
@time compute_spec_rad(ez, ssyd)
# Out:
#   0.077023 seconds (100.38 k allocations: 2.747 MiB)
# 1.0044344933009652
