# %% [markdown]
# ## Stability in the BY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinBY()
by = BYConsumption()
# Out:
# BYConsumption{Float64}(0.0015, 0.979, 0.044, 0.987, 7.9092e-7, 2.3e-6)

# %%
compute_ez_coef(ez, by)
# Out:
# 1.0028674069843384

# %%
@time compute_spec_rad_coef(ez, by, M=1000, N=5000)
# Out:
#   0.521262 seconds (35.13 M allocations: 617.383 MiB, 5.54% gc time)
# 0.9982951822069128

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("by", :ψ, 1.1, 4.0, :μ_c, 0.0012, 0.0045, G=20, method="ez", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f93a7385a58>)

# %%
stability_plot("by", :ψ, 1.1, 4.0, :μ_c, 0.0012, 0.0045, G=20, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f939bb31ef0>)
