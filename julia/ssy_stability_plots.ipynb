# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", :ψ, 1.05, 2.5, :μ_c, 0.0012, 0.005, G=20, method="ez", coords=(-125, 30))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4b2f6aa58>)

# %%
stability_plot("ssy", :ψ, 1.1, 2.5, :μ_c, 0.0012, 0.005, G=20, coords=(-125, 30))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4a771b2e8>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy",  :β, 0.997, 0.9999, :ψ, 1.25, 3.5, G=20, method="ez")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4a70e6978>)

# %%
stability_plot("ssy", :β, 0.997, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4a3a54f28>)
