# %% [markdown]
# # SSY Dicretization and the Test Value
#
# How does discretization affect the test value?

# %%
import numpy as np
import matplotlib.pyplot as plt
import quantecon as qe

# %%
# %run src/ssy_discretized_test.py

# %%
s = SSY()

# %%
def continuous_call(D, num_reps=25):
    f = mc_factory(s, K=D, I=D, J=D)
    out = np.empty(num_reps)
    for i in range(num_reps):
        out[i] = f(n=1000, m=1000)
    return out.mean()

# %%
lambda_vals = []
D1, D2 = 5, 40

# %%
for D in range(D1, D2):
    lambda_vals.append(continuous_call(D))

# %%
fig, ax = plt.subplots()
ax.plot(range(D1, D2), np.array(lambda_vals), label="value of $\Lambda$ computed by Monte Carlo")
ax.set_xlabel("level of discretization", fontsize=12)
ax.set_ylim((0.999, 1.0))
ax.legend(fontsize=12, loc="upper right")
plt.show()
