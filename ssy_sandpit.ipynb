# %%
using PyPlot
plt = PyPlot
# Out:
# PyPlot

# %%
include("src/ssy_stability.jl")
# Out:
# compute_mm_coef

# %%
ez = EpsteinZinSSY()
sc = SSYConsumption()
# Out:
# SSYConsumption{Float64}(0.0016, 0.987, 0.215, 0.0032, 1.0, 0.992, 0.06244997998398398, 0.991, 0.09797958971132711)

# %%
@time s = compute_spec_rad_coef(ez, sc, M=1000, N=5000)
# Out:
#   2.995433 seconds (90.10 M allocations: 1.569 GiB, 1.78% gc time)
# 0.8894512510151937

# %% [markdown]
# Test that initial conditions don't matter:

# %%
zs = linspace(-0.004, 0.004, 14)
ss = [compute_spec_rad_by_sim(ez, sc, z0=z, M=2000, N=5000) for z in zs]
# Out:
# 14-element Array{Float64,1}:
#  1.00691
#  1.00793
#  1.00732
#  1.0075
#  1.00647
#  1.00657
#  1.00682
#  1.00658
#  1.00705
#  1.00674
#  1.00602
#  1.00648
#  1.00745
#  1.00603

# %%
plt.plot(zs, ss)
plt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f42bfec46d8>)
