# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# stability_plot (generic function with 1 method)

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", :ψ, 1.05, 2.5, :μ_c, 0.0012, 0.005, G=20, method="mm", coords=(-125, 30))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9fdcf86cc0>)

# %%
stability_plot("ssy", :ψ, 1.1, 2.5, :μ_c, 0.0012, 0.005, G=20, coords=(-125, 30))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9fd1e882b0>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy",  :β, 0.997, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9fd1aead68>)

# %%
stability_plot("ssy", :β, 0.997, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9fced33b70>)
