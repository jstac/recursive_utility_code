# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
ez = EpsteinZinSSY()
# Out:
# EpsteinZin{Float64}(1.97, 8.89, 0.999)

# %%
ssy = SSYconsumption()
# Out:
# SSYconsumption{Float64}(0.0016, 0.987, 0.215, 0.0032, 1.0, 0.992, 0.06244997998398398, 0.991, 0.09797958971132711)

# %%
ssyd = discretize(ssy, 8, 8, 8)
# Out:
# SSYconsumptionDiscretized{Float64}(SSYconsumption{Float64}(0.0016, 0.987, 0.215, 0.0032, 1.0, 0.992, 0.06244997998398398, 0.991, 0.09797958971132711), 8, 8, 8, [0.000461444, 0.000802442, 0.00139543, 0.00242663, 0.00421985, 0.00733824, 0.0127611, 0.0221912], [0.000185849, 0.000270127, 0.000392623, 0.000570669, 0.000829454, 0.00120559, 0.0017523, 0.00254693], [-0.00049171 -0.000351221 … 0.000351221 0.00049171; -0.000714689 -0.000510492 … 0.000510492 0.000714689; … ; -0.00463615 -0.00331154 … 0.00331154 0.00463615; -0.00673854 -0.00481325 … 0.00481325 0.00673854], [0.000461444 0.000461444 … 0.0221912 0.0221912; 0.000185849 0.000185849 … 0.00254693 0.00254693; -0.00049171 -0.000351221 … 0.00481325 0.00673854], [0.900076 0.0412214 … 3.2111e-46 3.00124e-49; 0.00588877 0.900307 … 4.20692e-44 4.58728e-47; … ; 4.58728e-47 4.20692e-44 … 0.900307 0.00588877; 3.00124e-49 3.2111e-46 … 0.0412214 0.900076])

# %%
compute_mm_coef(ez, ssyd)
# Out:
# 1.0510623173432025

# %%
@time compute_spec_rad(ez, ssyd)
# Out:
#   0.568782 seconds (680.00 k allocations: 22.268 MiB, 0.98% gc time)
# 1.0112434931157073

# %%
8^3
# Out:
# 512

# %%
(1 - ez.γ) / (1 - 1/ez.ψ)
# Out:
# -16.0240206185567

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", [8, 8, 8], :ψ, 1.01, 2.1, :μ, 0.0005, 0.006, G=25, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3f0ff3f6a0>)

# %%
stability_plot("ssy", [8, 8, 8], :ψ, 1.01, 2.1, :μ, 0.0005, 0.006, G=25)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3f06232390>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy", [8, 8, 8], :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3f02b13f98>)

# %%
stability_plot("ssy", [8, 8, 8], :β, 0.975, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3f05f27a20>)

# %% [markdown]
# ### rho vs beta
