# %% [markdown]
# ## Stability in the SSY Model

# %%
include("src/stability_plots.jl")
# Out:
# WARNING: replacing docs for 'EpsteinZin :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinBY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'EpsteinZinSSY :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Union{}' in module 'Main'.
# WARNING: replacing docs for 'BYconsumption :: Tuple{}' in module 'Main'.
# WARNING: replacing docs for 'compute_bounds :: Tuple{BYconsumption}' in module 'Main'.
# WARNING: replacing docs for 'K_interp :: Tuple{EpsteinZin,BYconsumption,Array{Float64,2},Array{Float64,2},AbstractArray{T,1} where T,AbstractArray{T,1} where T,Array{Float64,1},Array{Float64,1}}' in module 'Main'.
# WARNING: replacing docs for 'K_interp! :: Tuple{EpsteinZin,BYconsumption,Array{Float64,2},Array{Float64,2},AbstractArray{T,1} where T,AbstractArray{T,1} where T}' in module 'Main'.
# WARNING: replacing docs for 'compute_spec_rad_interp! :: Tuple{EpsteinZin,BYconsumption,Any,Any,Any}' in module 'Main'.
# ...

# %% [markdown]
# ### mu vs psi

# %%
stability_plot("ssy", :ψ, 1.1, 4.5, :μ, 0.0012, 0.005, G=25, method="mm", coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f30589d9358>)

# %%
stability_plot("ssy", :ψ, 1.1, 4.5, :μ, 0.0012, 0.005, G=25, coords=(25, 25))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3012190e80>)

# %% [markdown]
# ### psi vs beta

# %%
stability_plot("ssy",  :β, 0.996, 0.9999, :ψ, 1.25, 3.5, G=20, method="mm")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f3012046d30>)

# %%
stability_plot("ssy", :β, 0.996, 0.9999, :ψ, 1.25, 3.5, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f301215fe80>)
